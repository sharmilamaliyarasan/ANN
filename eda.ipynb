# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Iris_extended.csv")

# %%
df.size
# Out:
# 5000

# %%
df.shape
# Out:
# (1000, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  1000 non-null   float64
#  1   SepalWidthCm   1000 non-null   float64
#  2   PetalLengthCm  1000 non-null   float64
#  3   PetalWidthCm   1000 non-null   float64
#  4   Species        1000 non-null   object
# dtypes: float64(4), object(1)
# memory usage: 39.2+ KB

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count    1000.000000   1000.000000    1000.000000   1000.000000
# mean        5.853700      3.051900       3.789400      1.212100
# std         0.827666      0.434632       1.764103      0.770777
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.250000      1.300000
# 75%         6.400000      3.300000       5.200000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
df.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(853)

# %%
print("Class Distribution:")
print(df["Species"].value_counts())
sns.countplot(x="Species", data=df)
plt.title("Class Distribution")
plt.show()
# Out:
# Class Distribution:
# Species
# Iris-virginica     351
# Iris-setosa        325
# Iris-versicolor    324
# Name: count, dtype: int64

# %%
features = ["SepalLengthCm", "SepalWidthCm", "PetalLengthCm", "PetalWidthCm"]

# %%
for col in features:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col], kde=True, bins=30)

    skewness = df[col].skew()
    plt.title(f"Distribution of {col}\nSkewness = {skewness:.2f}")
    plt.show()
    
    if abs(skewness) > 1:
        plt.figure(figsize=(6,4))
        sns.histplot(np.log1p(df[col]), kde=True, bins=30)
        plt.title(f"Log-Transformed Distribution of {col}")
        plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.drop(columns=["Species"]).corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
